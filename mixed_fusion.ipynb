# %%
import os
import random
from tqdm import tqdm
import numpy as np
import time
import logging
import sys
import copy
import gc
# draw metrics
from sklearn.metrics import roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt

import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.datasets as datasets
from torch.utils.data.dataset import Dataset
import torchvision.models as models
from torchvision.models import AlexNet_Weights
import torchmetrics

import torchvision.transforms as transforms
from torchvision.transforms import Compose 
from torch.utils.tensorboard import SummaryWriter
torch.backends.cudnn.benchmark=True
print(sys.executable)
print(sys.version)
print(torch.cuda.is_available())
print(f'Torchvision version: {torchvision.__version__}')
# Out:
# c:\Users\jizhi\.conda\envs\flv1\python.exe
# 3.8.18 (default, Sep 11 2023, 13:39:12) [MSC v.1916 64 bit (AMD64)]
# True
# Torchvision version: 0.16.0

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

seed_value = 42
set_seed(seed_value)

# %%
# set logger
# create logger
logger = logging.getLogger(__name__)
# set log level for all handlers to debug
logger.setLevel(logging.DEBUG)

# create console handler and set level to debug
# best for development or debugging
consoleHandler = logging.StreamHandler()
consoleHandler.setLevel(logging.DEBUG)

# create formatter
# formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
formatter = logging.Formatter('%(asctime)s-%(levelname)s: %(message)s')

# add formatter to ch
consoleHandler.setFormatter(formatter)

# add ch to logger
logger.addHandler(consoleHandler)

# %%
##### Hyperparameters for federated learning #########
epochs_ = 50
batch_size_ = 16

writer_ = SummaryWriter('runs\\sim-fusion-alexnet\\')

# CUDA_LAUNCH_BLOCKING=1

# %%
# prepare image
train_names_list = ['hospital','sim-room','warehouse']

val_names_list = ['hospital','sim-room','warehouse','overall']

train_data_folders_list = [ 'C:\\Users\\jizhi\\Desktop\\study\\FL\\federated_learning\\fl_data\\mine\\sim_train\\hospital\\train',
                            'C:\\Users\\jizhi\\Desktop\\study\\FL\\federated_learning\\fl_data\\mine\\sim_train\\sim-room\\train',
                            'C:\\Users\\jizhi\\Desktop\\study\\FL\\federated_learning\\fl_data\\mine\\sim_train\\warehouse\\train',
                    ]

val_data_folders_list = [ 'C:\\Users\\jizhi\\Desktop\\study\\FL\\federated_learning\\fl_data\\mine\\sim_train\\hospital\\test',
                            'C:\\Users\\jizhi\\Desktop\\study\\FL\\federated_learning\\fl_data\\mine\\sim_train\\sim-room\\test',
                            'C:\\Users\\jizhi\\Desktop\\study\\FL\\federated_learning\\fl_data\\mine\\sim_train\\warehouse\\test',
                            'C:\\Users\\jizhi\\Desktop\\study\\FL\\federated_learning\\fl_data\\mine\\sim_train\\overall\\test',
                    ]

transformed_train_datasets, transformed_val_datasets = [], []


################################################  Data Loaders  #####################################
# 在这个部分，为训练和验证的图像数据定义了一些预处理步骤，包括颜色抖动、重新调整大小、转换为张量和归一化。
# 这些预处理步骤通过 PyTorch 的 transforms 模块实现，并且它们将在训练过程中应用到每个图像上。
for train_dataset in train_data_folders_list:
    transformed_train_datasets.append(
        datasets.ImageFolder(
            train_dataset,
            transforms.Compose([
                transforms.ColorJitter(0.1, 0.1, 0.1, 0.1),
                transforms.Resize((224, 224)),
                transforms.ToTensor(),
                transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ])
        )
    ) 

for val_dataset in val_data_folders_list:
    transformed_val_datasets.append(
        datasets.ImageFolder(
            val_dataset,
            transforms.Compose([
                transforms.ColorJitter(0.1, 0.1, 0.1, 0.1),
                transforms.Resize((224, 224)),
                transforms.ToTensor(),
                transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ])
        )
    ) 

#########  Data Loaders  ##########

train_loader_list, val_loader_list = [], []

for train_d in transformed_train_datasets:
    train_loader_list.append(
        torch.utils.data.DataLoader(
                train_d,
                batch_size=batch_size_,
                shuffle=True,
                num_workers=4,
                drop_last = False,
            )
    )

for val_d in transformed_val_datasets:
    val_loader_list.append(
        torch.utils.data.DataLoader(
                val_d,
                batch_size=1,
                shuffle=True,
                num_workers=4,
                drop_last = False,
            )
    )

#########   Model Fusion Setup  #########

fusion_model_list = [(0,1), (0,2),(1,2),(0,1,2)]

fusion_model_pathes =[]
fusion_names_ = []
logger.info("The number of different fusion models: {}".format(len(fusion_model_list)))
for data in fusion_model_list:
    fusion_model_path = "C:\\Users\\jizhi\\Desktop\\study\\FL\\federated_learning\\fl_results\\saved_models\\sim\\fusion_models\\my_fusion_model_on"
    fusion_name = ''
    for d in data:
        fusion_model_path = fusion_model_path  + "_" + train_names_list[d]
        fusion_name = fusion_name + "_" + train_names_list[d]
    #fusion_model_path =  fusion_model_path + ".pth"

    logger.info("Fusion model names: {}".format(fusion_name))
    logger.info("Fusion model save path: {}".format(fusion_model_path ))

    fusion_model_pathes.append(fusion_model_path)
    fusion_names_.append(fusion_name)
# Out:
# 2023-10-29 01:37:57,189-INFO: The number of different fusion models: 4
# 2023-10-29 01:37:57,190-INFO: Fusion model names: _hospital_sim-room
# 2023-10-29 01:37:57,191-INFO: Fusion model save path: C:\Users\jizhi\Desktop\study\FL\federated_learning\fl_results\saved_models\sim\fusion_models\my_fusion_model_on_hospital_sim-room
# 2023-10-29 01:37:57,191-INFO: Fusion model names: _hospital_warehouse
# 2023-10-29 01:37:57,192-INFO: Fusion model save path: C:\Users\jizhi\Desktop\study\FL\federated_learning\fl_results\saved_models\sim\fusion_models\my_fusion_model_on_hospital_warehouse
# 2023-10-29 01:37:57,192-INFO: Fusion model names: _sim-room_warehouse
# 2023-10-29 01:37:57,193-INFO: Fusion model save path: C:\Users\jizhi\Desktop\study\FL\federated_learning\fl_results\saved_models\sim\fusion_models\my_fusion_model_on_sim-room_warehouse
# 2023-10-29 01:37:57,194-INFO: Fusion model names: _hospital_sim-room_warehouse
# 2023-10-29 01:37:57,195-INFO: Fusion model save path: C:\Users\jizhi\Desktop\study\FL\federated_learning\fl_results\saved_models\sim\fusion_models\my_fusion_model_on_hospital_sim-room_warehouse

# %%
def server_aggregate_weighted(global_model, client_models, client_lens):
    """
    This function has aggregation method 'wmean'
    wmean takes the weighted mean of the weights of models
    """
    total = sum(client_lens)
    n = len(client_models)
    global_dict = global_model.state_dict()

    #momentum = {kk: (print(f"Key: {kk}, Value: {vv}"), torch.zeros_like(vv))[1] for kk, vv in global_dict.items()}
    for k in global_dict.keys():
        #global_dict[k] = torch.stack([client_models[i].state_dict()[k].float()*(n*client_lens[i]/total) for i in range(n)], 0).mean(0)
        global_dict[k] = torch.sum(torch.stack([client_models[i].state_dict()[k].float() * (client_lens[i]/total) for i in range(n)], 0), dim=0)
    global_model.load_state_dict(global_dict)

def server_aggregate_simple(global_model, client_models):
    global_dict = global_model.state_dict()
    n = len(client_models)
    for k in global_dict.keys():
        global_dict[k] = torch.stack([client_models[i].state_dict()[k].float() for i in range(n)], 0).mean(0)
    global_model.load_state_dict(global_dict)


def server_aggregate_median(global_model, client_models):
    global_dict = global_model.state_dict()
    n = len(client_models)
    for k in global_dict.keys():
        global_dict[k] = torch.median(torch.stack([client_models[i].state_dict()[k].float() for i in range(n)], 0), 0).values
    global_model.load_state_dict(global_dict)


def server_aggregate_momentum(global_model, client_models, alpha=0.9):
    global_dict = global_model.state_dict()
    momentum = {k: torch.zeros_like(v) for k, v in global_dict.items()}
    for k in global_dict.keys():
        new_value = torch.stack([client_models[i].state_dict()[k].float() for i in range(len(client_models))], 0).mean(0)
        momentum[k] = alpha * momentum[k] + (1 - alpha) * new_value
        global_dict[k] += momentum[k]
    global_model.load_state_dict(global_dict)


def server_aggregate_personalized(global_model, client_models, alpha=0.1):
    global_dict = global_model.state_dict()
    for k, v in global_dict.items():
        client_updates = torch.stack([m.state_dict()[k] for m in client_models])
        global_dict[k] = alpha * v + (1 - alpha) * torch.mean(client_updates, dim=0)
    global_model.load_state_dict(global_dict)


def server_aggregate_dp(global_model, client_models, client_lens, epsilon=1.0):
    """
    This function has aggregation method 'Differential Privacy average'
    It adds Laplace noise for differential privacy.
    """
    total = sum(client_lens)
    n = len(client_models)
    global_dict = global_model.state_dict()
    
    for k in global_dict.keys():
        # Calculate the weighted mean as before
        aggregated_weight = torch.stack(
            [client_models[i].state_dict()[k].float() * (client_lens[i]/total) for i in range(len(client_models))],
            0
        ).sum(0)
        
        # Add Laplace noise for differential privacy
        laplace_noise = torch.from_numpy(
            np.random.laplace(0, 1.0 / epsilon, aggregated_weight.shape)
        ).float()
        
        # Combine true answer and noise
        global_dict[k] = aggregated_weight + laplace_noise.to(aggregated_weight.device)

    global_model.load_state_dict(global_dict)


def server_aggregate_quantization(global_model, client_models, client_lens, quantization_level=8):
    """
    This function has aggregation method 'q-FedAvg' which quantizes the updates before averaging
    """
    total = sum(client_lens)
    global_dict = global_model.state_dict()
    n = len(client_models)

    for k in global_dict.keys():
        # Quantize each client's updates
        quantized_client_weights = [
            torch.round(client_models[i].state_dict()[k].float() * (2 ** quantization_level - 1)) / (2 ** quantization_level - 1)
            for i in range(len(client_models))
        ]

        # Perform weighted averaging on quantized updates
        global_dict[k] = torch.stack([quantized_client_weights[i] * (n*client_lens[i] / total) for i in range(len(client_models))], 0).mean(0)


    global_model.load_state_dict(global_dict)

# %%
def test(model_name, writer, current_epoch, model, test_loader):
    """
    This function test the global model on test 
    data and returns test loss and test accuracy 
    """
    model.eval()

    #test_loss = 0
    #correct = 0
    test_error_count1 = 0
    with torch.no_grad():
        for image, label in test_loader:#以batch为单位取值
            image, label = image.cuda(), label.cuda()
            outputs = model(image)

            test_error_count1 += float(torch.sum(torch.abs(label - outputs.argmax(1))))
        # 用于计算测试阶段的平均损失
        #test_loss /= len(test_loader.dataset)


        acc = 1.0 - float(test_error_count1) / float(len(test_loader.dataset))
        writer.add_scalar("Val-Acc/"+model_name, acc, current_epoch)

    return acc

def client_syn(client_model, global_model):
  '''
  This function synchronizes the client model with global model
  '''
  client_model.load_state_dict(global_model.state_dict())

# %%
aggregation_methods = [server_aggregate_weighted, server_aggregate_simple, server_aggregate_median, server_aggregate_momentum, server_aggregate_personalized, server_aggregate_dp, server_aggregate_quantization]

model = models.alexnet(weights=AlexNet_Weights.IMAGENET1K_V1)

for param in model.parameters():
    param.requires_grad = False

# 这行代码修改了AlexNet模型分类器的最后一层。它将最后一层的输出特征数从原始的1000（AlexNet在ImageNet上的分类数）改为了2。
model.classifier[6] = torch.nn.Linear(model.classifier[6].in_features, 2)

device = torch.device('cuda')

############################## client models ##############################


for agg_method in aggregation_methods:  # 添加这个循环,尝试不同的聚合方法
    global_models = [copy.deepcopy(model).to(device) for _ in range(len(fusion_model_list))]######复制了4个model
    for idx, fusion_pair in enumerate(fusion_model_list):

        client_models = [copy.deepcopy(model).to(device) for _ in range(len(fusion_pair))]

        optims_list = [optim.SGD(client_model.parameters(), lr=0.001, momentum=0.9) for client_model in client_models]

        client_lens = [len(train_loader_list[idx]) for idx in fusion_pair]
        '''
        It gives the number of batches in the training dataset for the corresponding client.
        In Federated Learning, the size of each client's dataset is often used as a weight when aggregating the models from the clients, 
        since clients with larger datasets generally contribute more to the learning process. 
        The client_lens list could be used for this purpose in the server-side model aggregation function.
        '''

        logger.info("-----------------------Fusion model names:{}--------------------------".format(fusion_names_[idx]))

        #这行代码创建了一个梯度缩放器，它通常用于半精度（float16）训练，这可以加速训练并减少GPU内存使用。如果你不打算使用半精度训练，这个部分可以忽略。
        scalers_list = [torch.cuda.amp.GradScaler() for _ in range(len(fusion_pair))]

        best_acc = 0.0
        for i in range(epochs_):
            
            for it in range(len(fusion_pair)):
                client_syn(client_models[it], global_models[idx])  
                #print(f'------ Train Epoch: {i}, Client: {train_names_list[fusion_pair[it]]},  ------')
                for images, labels in iter(train_loader_list[fusion_pair[it]]):

                    images = images.to(device)
                    labels = labels.to(device)
                    optims_list[it].zero_grad()
                    with torch.cuda.amp.autocast_mode.autocast():
                        outputs = client_models[it](images)
                        loss = F.cross_entropy(outputs, labels)
                    scaler = scalers_list[it]
                    scaler.scale(loss).backward()
                    scaler.step(optims_list[it])
                    scaler.update()

            if agg_method == server_aggregate_weighted or agg_method == server_aggregate_quantization or agg_method == server_aggregate_dp:
                agg_method(global_models[idx], client_models, client_lens)
            else:
                agg_method(global_models[idx], client_models)

            val_inx  = 3 #用overall数据集来决定最后存储的模型
            val_data = val_loader_list[val_inx]

            acc = test("Fusion_Models_:{}-On-Val-Data-{}".format(fusion_names_[idx], val_names_list[val_inx]), writer_, i, global_models[idx],  val_data)
            logger.info("Fusion Model:{}, Agg_method:{}, Epoch:{}, Val_Data:{}, Accuracy:{}.".format(fusion_names_[idx], agg_method.__name__, val_names_list[val_inx], i, acc))

            if acc > best_acc and acc < 1.0:
                best_acc = acc
                save_path = f"{fusion_model_pathes[idx]}_{agg_method.__name__}.pth"
                torch.save(global_models[idx].state_dict(), save_path)
        logger.info("Final Fusion Model:{}, Agg_method:{}, Best Accuracy:{}.".format(fusion_names_[idx], agg_method.__name__,best_acc))
        
        # After you're done with the client models and the optimizer, you can free up the memory
        for client_model, optim_ in zip(client_models, optims_list):
            del client_model
            del optim_
        torch.cuda.empty_cache()  # Clear GPU cache
    
    logger.info("---------------Agg_method:{}:DONE!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!---------------.".format(agg_method.__name__))
    # After you're done with the global models, you can free up the memory
    for global_model in global_models:
        del global_model
    torch.cuda.empty_cache()  # Clear GPU cache
    # Manually run Python's garbage collection
    gc.collect()

logger.info("DONE!!!!!!!!")
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to C:\Users\jizhi/.cache\torch\hub\checkpoints\alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:21<00:00, 11.4MB/s]
# 2023-10-29 01:38:24,565-INFO: -----------------------Fusion model names:_hospital_sim-room--------------------------
# 2023-10-29 01:39:10,607-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:0, Accuracy:0.9230769230769231.
# 2023-10-29 01:39:55,871-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:1, Accuracy:0.9615384615384616.
# 2023-10-29 01:40:41,647-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:2, Accuracy:0.9615384615384616.
# 2023-10-29 01:41:25,699-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:3, Accuracy:0.9735576923076923.
# 2023-10-29 01:42:12,187-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:4, Accuracy:0.9086538461538461.
# 2023-10-29 01:42:57,250-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:5, Accuracy:0.9134615384615384.
# 2023-10-29 01:43:41,252-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:6, Accuracy:0.9038461538461539.
# 2023-10-29 01:44:25,936-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:7, Accuracy:0.9591346153846154.
# 2023-10-29 01:45:09,841-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:8, Accuracy:0.8918269230769231.
# 2023-10-29 01:45:54,472-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:9, Accuracy:0.8413461538461539.
# 2023-10-29 01:46:38,887-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:10, Accuracy:0.875.
# 2023-10-29 01:47:22,855-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:11, Accuracy:0.8509615384615384.
# 2023-10-29 01:48:06,969-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:12, Accuracy:0.8485576923076923.
# 2023-10-29 01:48:51,241-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:13, Accuracy:0.8629807692307692.
# 2023-10-29 01:49:35,322-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:14, Accuracy:0.8509615384615384.
# 2023-10-29 01:50:19,598-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:15, Accuracy:0.8774038461538461.
# 2023-10-29 01:51:03,825-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:16, Accuracy:0.8822115384615384.
# 2023-10-29 01:51:47,916-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:17, Accuracy:0.8461538461538461.
# 2023-10-29 01:52:32,133-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:18, Accuracy:0.84375.
# 2023-10-29 01:53:16,020-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:19, Accuracy:0.8605769230769231.
# 2023-10-29 01:53:59,950-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:20, Accuracy:0.8485576923076923.
# 2023-10-29 01:54:44,307-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:21, Accuracy:0.8509615384615384.
# 2023-10-29 01:55:28,868-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:22, Accuracy:0.8677884615384616.
# 2023-10-29 01:56:13,030-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:23, Accuracy:0.8653846153846154.
# 2023-10-29 01:56:57,110-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:24, Accuracy:0.90625.
# 2023-10-29 01:57:41,362-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:25, Accuracy:0.84375.
# 2023-10-29 01:58:25,895-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:26, Accuracy:0.8509615384615384.
# 2023-10-29 01:59:10,007-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:27, Accuracy:0.8485576923076923.
# 2023-10-29 01:59:53,895-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:28, Accuracy:0.8485576923076923.
# 2023-10-29 02:00:38,271-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:29, Accuracy:0.8485576923076923.
# 2023-10-29 02:01:22,410-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:30, Accuracy:0.8581730769230769.
# 2023-10-29 02:02:06,882-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:31, Accuracy:0.8509615384615384.
# 2023-10-29 02:02:51,287-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:32, Accuracy:0.8485576923076923.
# 2023-10-29 02:03:36,010-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:33, Accuracy:0.875.
# 2023-10-29 02:04:16,543-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:34, Accuracy:0.8557692307692308.
# 2023-10-29 02:04:56,863-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:35, Accuracy:0.8509615384615384.
# 2023-10-29 02:05:38,626-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:36, Accuracy:0.8533653846153846.
# 2023-10-29 02:06:20,109-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:37, Accuracy:0.8557692307692308.
# 2023-10-29 02:07:01,536-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:38, Accuracy:0.8557692307692308.
# 2023-10-29 02:07:42,756-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:39, Accuracy:0.8725961538461539.
# 2023-10-29 02:08:24,364-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:40, Accuracy:0.8677884615384616.
# 2023-10-29 02:09:05,844-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:41, Accuracy:0.8677884615384616.
# 2023-10-29 02:09:47,100-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:42, Accuracy:0.8605769230769231.
# 2023-10-29 02:10:27,951-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:43, Accuracy:0.8629807692307692.
# 2023-10-29 02:11:08,728-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:44, Accuracy:0.8677884615384616.
# 2023-10-29 02:11:49,703-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:45, Accuracy:0.875.
# 2023-10-29 02:12:31,142-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:46, Accuracy:0.875.
# 2023-10-29 02:13:12,564-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:47, Accuracy:0.8725961538461539.
# 2023-10-29 02:13:53,765-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:48, Accuracy:0.8653846153846154.
# 2023-10-29 02:14:36,240-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:49, Accuracy:0.8629807692307692.
# 2023-10-29 02:14:36,241-INFO: Final Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_weighted, Best Accuracy:0.9735576923076923.
# 2023-10-29 02:14:36,510-INFO: -----------------------Fusion model names:_hospital_warehouse--------------------------
# 2023-10-29 02:15:28,351-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:0, Accuracy:0.8533653846153846.
# 2023-10-29 02:16:15,166-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:1, Accuracy:0.8581730769230769.
# 2023-10-29 02:17:02,839-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:2, Accuracy:0.8485576923076923.
# 2023-10-29 02:17:50,884-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:3, Accuracy:0.8653846153846154.
# 2023-10-29 02:18:39,068-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:4, Accuracy:0.8725961538461539.
# 2023-10-29 02:19:26,971-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:5, Accuracy:0.8653846153846154.
# 2023-10-29 02:20:14,415-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:6, Accuracy:0.8653846153846154.
# 2023-10-29 02:21:01,801-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:7, Accuracy:0.8725961538461539.
# 2023-10-29 02:21:49,432-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:8, Accuracy:0.8870192307692307.
# 2023-10-29 02:22:37,436-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:9, Accuracy:0.8774038461538461.
# 2023-10-29 02:23:25,410-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:10, Accuracy:0.8725961538461539.
# 2023-10-29 02:24:13,335-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:11, Accuracy:0.8846153846153846.
# 2023-10-29 02:25:02,681-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:12, Accuracy:0.8798076923076923.
# 2023-10-29 02:25:53,926-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:13, Accuracy:0.8870192307692307.
# 2023-10-29 02:26:44,884-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:14, Accuracy:0.8894230769230769.
# 2023-10-29 02:27:37,138-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:15, Accuracy:0.8942307692307693.
# 2023-10-29 02:28:31,397-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:16, Accuracy:0.8846153846153846.
# 2023-10-29 02:29:23,063-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:17, Accuracy:0.8894230769230769.
# 2023-10-29 02:30:14,865-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:18, Accuracy:0.8966346153846154.
# 2023-10-29 02:31:07,182-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:19, Accuracy:0.8966346153846154.
# 2023-10-29 02:31:59,155-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:20, Accuracy:0.8990384615384616.
# 2023-10-29 02:32:51,054-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:21, Accuracy:0.9038461538461539.
# 2023-10-29 02:33:43,035-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:22, Accuracy:0.8990384615384616.
# 2023-10-29 02:34:34,799-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:23, Accuracy:0.8966346153846154.
# 2023-10-29 02:35:26,624-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:24, Accuracy:0.9038461538461539.
# 2023-10-29 02:36:18,333-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:25, Accuracy:0.9038461538461539.
# 2023-10-29 02:37:10,149-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:26, Accuracy:0.9134615384615384.
# 2023-10-29 02:38:02,172-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:27, Accuracy:0.9206730769230769.
# 2023-10-29 02:38:54,623-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:28, Accuracy:0.9182692307692307.
# 2023-10-29 02:39:46,185-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:29, Accuracy:0.9086538461538461.
# 2023-10-29 02:40:37,245-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:30, Accuracy:0.9014423076923077.
# 2023-10-29 02:41:28,154-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:31, Accuracy:0.9278846153846154.
# 2023-10-29 02:42:19,855-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:32, Accuracy:0.9254807692307693.
# 2023-10-29 02:43:12,070-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:33, Accuracy:0.9086538461538461.
# 2023-10-29 02:44:03,805-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:34, Accuracy:0.9134615384615384.
# 2023-10-29 02:44:55,773-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:35, Accuracy:0.9158653846153846.
# 2023-10-29 02:45:47,432-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:36, Accuracy:0.9230769230769231.
# 2023-10-29 02:46:39,367-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:37, Accuracy:0.9302884615384616.
# 2023-10-29 02:47:31,302-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:38, Accuracy:0.9182692307692307.
# 2023-10-29 02:48:22,998-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:39, Accuracy:0.9302884615384616.
# 2023-10-29 02:49:14,721-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:40, Accuracy:0.9158653846153846.
# 2023-10-29 02:50:06,336-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:41, Accuracy:0.9254807692307693.
# 2023-10-29 02:50:58,846-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:42, Accuracy:0.9206730769230769.
# 2023-10-29 02:51:51,008-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:43, Accuracy:0.9254807692307693.
# 2023-10-29 02:52:42,807-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:44, Accuracy:0.9230769230769231.
# 2023-10-29 02:53:34,624-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:45, Accuracy:0.9326923076923077.
# 2023-10-29 02:54:26,901-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:46, Accuracy:0.90625.
# 2023-10-29 02:55:18,513-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:47, Accuracy:0.9254807692307693.
# 2023-10-29 02:56:10,170-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:48, Accuracy:0.9326923076923077.
# 2023-10-29 02:57:01,904-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:49, Accuracy:0.9278846153846154.
# 2023-10-29 02:57:01,905-INFO: Final Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_weighted, Best Accuracy:0.9326923076923077.
# 2023-10-29 02:57:02,162-INFO: -----------------------Fusion model names:_sim-room_warehouse--------------------------
# 2023-10-29 02:57:51,738-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:0, Accuracy:0.8701923076923077.
# 2023-10-29 02:58:42,759-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:1, Accuracy:0.8725961538461539.
# 2023-10-29 02:59:33,377-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:2, Accuracy:0.8725961538461539.
# 2023-10-29 03:00:23,299-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:3, Accuracy:0.8725961538461539.
# 2023-10-29 03:01:13,649-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:4, Accuracy:0.8677884615384616.
# 2023-10-29 03:02:04,159-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:5, Accuracy:0.8725961538461539.
# 2023-10-29 03:02:54,545-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:6, Accuracy:0.8701923076923077.
# 2023-10-29 03:03:45,314-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:7, Accuracy:0.8677884615384616.
# 2023-10-29 03:04:35,812-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:8, Accuracy:0.875.
# 2023-10-29 03:05:26,037-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:9, Accuracy:0.8701923076923077.
# 2023-10-29 03:06:15,636-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:10, Accuracy:0.8701923076923077.
# 2023-10-29 03:07:05,638-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:11, Accuracy:0.8725961538461539.
# 2023-10-29 03:07:55,138-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:12, Accuracy:0.8725961538461539.
# 2023-10-29 03:08:44,904-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:13, Accuracy:0.8725961538461539.
# 2023-10-29 03:09:35,168-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:14, Accuracy:0.8725961538461539.
# 2023-10-29 03:10:24,764-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:15, Accuracy:0.8774038461538461.
# 2023-10-29 03:11:15,351-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:16, Accuracy:0.8725961538461539.
# 2023-10-29 03:12:05,683-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:17, Accuracy:0.8725961538461539.
# 2023-10-29 03:12:55,611-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:18, Accuracy:0.8725961538461539.
# 2023-10-29 03:13:46,065-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:19, Accuracy:0.8774038461538461.
# 2023-10-29 03:14:36,141-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:20, Accuracy:0.8725961538461539.
# 2023-10-29 03:15:26,061-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:21, Accuracy:0.875.
# 2023-10-29 03:16:15,846-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:22, Accuracy:0.8725961538461539.
# 2023-10-29 03:17:05,590-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:23, Accuracy:0.875.
# 2023-10-29 03:17:54,718-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:24, Accuracy:0.8725961538461539.
# 2023-10-29 03:18:44,870-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:25, Accuracy:0.875.
# 2023-10-29 03:19:35,016-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:26, Accuracy:0.8725961538461539.
# 2023-10-29 03:20:24,859-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:27, Accuracy:0.8725961538461539.
# 2023-10-29 03:21:14,504-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:28, Accuracy:0.8701923076923077.
# 2023-10-29 03:22:04,257-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:29, Accuracy:0.875.
# 2023-10-29 03:22:54,382-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:30, Accuracy:0.8701923076923077.
# 2023-10-29 03:23:44,525-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:31, Accuracy:0.8701923076923077.
# 2023-10-29 03:24:34,727-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:32, Accuracy:0.8725961538461539.
# 2023-10-29 03:25:24,468-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:33, Accuracy:0.875.
# 2023-10-29 03:26:14,539-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:34, Accuracy:0.8725961538461539.
# 2023-10-29 03:27:04,694-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:35, Accuracy:0.875.
# 2023-10-29 03:27:54,857-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:36, Accuracy:0.8774038461538461.
# 2023-10-29 03:28:44,777-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:37, Accuracy:0.8798076923076923.
# 2023-10-29 03:29:35,754-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:38, Accuracy:0.875.
# 2023-10-29 03:30:25,463-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:39, Accuracy:0.8725961538461539.
# 2023-10-29 03:31:15,480-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:40, Accuracy:0.875.
# 2023-10-29 03:32:05,683-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:41, Accuracy:0.8774038461538461.
# 2023-10-29 03:32:56,164-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:42, Accuracy:0.875.
# 2023-10-29 03:33:46,099-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:43, Accuracy:0.8774038461538461.
# 2023-10-29 03:34:36,353-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:44, Accuracy:0.875.
# 2023-10-29 03:35:26,363-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:45, Accuracy:0.8774038461538461.
# 2023-10-29 03:36:16,601-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:46, Accuracy:0.8774038461538461.
# 2023-10-29 03:37:06,962-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:47, Accuracy:0.875.
# 2023-10-29 03:37:56,959-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:48, Accuracy:0.875.
# 2023-10-29 03:38:47,124-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:49, Accuracy:0.8774038461538461.
# 2023-10-29 03:38:47,126-INFO: Final Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_weighted, Best Accuracy:0.8798076923076923.
# 2023-10-29 03:38:47,510-INFO: -----------------------Fusion model names:_hospital_sim-room_warehouse--------------------------
# 2023-10-29 03:39:52,502-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:0, Accuracy:0.8918269230769231.
# 2023-10-29 03:40:57,455-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:1, Accuracy:0.9206730769230769.
# 2023-10-29 03:42:00,992-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:2, Accuracy:0.9254807692307693.
# 2023-10-29 03:43:05,374-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:3, Accuracy:0.9423076923076923.
# 2023-10-29 03:44:09,499-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:4, Accuracy:0.9567307692307693.
# 2023-10-29 03:45:13,158-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:5, Accuracy:0.9639423076923077.
# 2023-10-29 03:46:16,655-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:6, Accuracy:0.9519230769230769.
# 2023-10-29 03:47:20,262-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:7, Accuracy:0.9615384615384616.
# 2023-10-29 03:48:24,332-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:8, Accuracy:0.9711538461538461.
# 2023-10-29 03:49:28,617-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:9, Accuracy:0.9759615384615384.
# 2023-10-29 03:50:32,768-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:10, Accuracy:0.9807692307692307.
# 2023-10-29 03:51:37,089-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:11, Accuracy:0.9783653846153846.
# 2023-10-29 03:52:40,919-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:12, Accuracy:0.9783653846153846.
# 2023-10-29 03:53:44,232-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:13, Accuracy:0.9759615384615384.
# 2023-10-29 03:54:47,627-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:14, Accuracy:0.9759615384615384.
# 2023-10-29 03:55:51,311-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:15, Accuracy:0.9783653846153846.
# 2023-10-29 03:56:54,479-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:16, Accuracy:0.9807692307692307.
# 2023-10-29 03:57:58,148-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:17, Accuracy:0.9783653846153846.
# 2023-10-29 03:59:02,170-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:18, Accuracy:0.9807692307692307.
# 2023-10-29 04:00:07,329-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:19, Accuracy:0.9807692307692307.
# 2023-10-29 04:01:11,029-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:20, Accuracy:0.9831730769230769.
# 2023-10-29 04:02:15,290-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:21, Accuracy:0.9831730769230769.
# 2023-10-29 04:03:19,427-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:22, Accuracy:0.9831730769230769.
# 2023-10-29 04:04:23,768-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:23, Accuracy:0.9807692307692307.
# 2023-10-29 04:05:27,234-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:24, Accuracy:0.9807692307692307.
# 2023-10-29 04:06:30,773-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:25, Accuracy:0.9807692307692307.
# 2023-10-29 04:07:34,361-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:26, Accuracy:0.9879807692307693.
# 2023-10-29 04:08:38,548-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:27, Accuracy:0.9831730769230769.
# 2023-10-29 04:09:42,230-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:28, Accuracy:0.9855769230769231.
# 2023-10-29 04:10:45,434-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:29, Accuracy:0.9855769230769231.
# 2023-10-29 04:11:49,099-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:30, Accuracy:0.9855769230769231.
# 2023-10-29 04:12:52,356-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:31, Accuracy:0.9783653846153846.
# 2023-10-29 04:13:56,259-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:32, Accuracy:0.9783653846153846.
# 2023-10-29 04:14:59,661-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:33, Accuracy:0.9783653846153846.
# 2023-10-29 04:16:03,423-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:34, Accuracy:0.9783653846153846.
# 2023-10-29 04:17:06,854-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:35, Accuracy:0.9831730769230769.
# 2023-10-29 04:18:10,471-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:36, Accuracy:0.9783653846153846.
# 2023-10-29 04:19:14,163-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:37, Accuracy:0.9855769230769231.
# 2023-10-29 04:20:17,676-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:38, Accuracy:0.9807692307692307.
# 2023-10-29 04:21:20,710-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:39, Accuracy:0.9879807692307693.
# 2023-10-29 04:22:24,237-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:40, Accuracy:0.9855769230769231.
# 2023-10-29 04:23:27,816-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:41, Accuracy:0.9879807692307693.
# 2023-10-29 04:24:31,632-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:42, Accuracy:0.9831730769230769.
# 2023-10-29 04:25:35,066-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:43, Accuracy:0.9807692307692307.
# 2023-10-29 04:26:38,903-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:44, Accuracy:0.9783653846153846.
# 2023-10-29 04:27:41,924-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:45, Accuracy:0.9855769230769231.
# 2023-10-29 04:28:45,550-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:46, Accuracy:0.9855769230769231.
# 2023-10-29 04:29:49,759-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:47, Accuracy:0.9831730769230769.
# 2023-10-29 04:30:53,619-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:48, Accuracy:0.9831730769230769.
# 2023-10-29 04:31:57,219-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Epoch:overall, Val_Data:49, Accuracy:0.9831730769230769.
# 2023-10-29 04:31:57,220-INFO: Final Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_weighted, Best Accuracy:0.9879807692307693.
# 2023-10-29 04:31:57,232-INFO: ---------------Agg_method:server_aggregate_weighted:DONE!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!---------------.
# 2023-10-29 04:31:57,915-INFO: -----------------------Fusion model names:_hospital_sim-room--------------------------
# 2023-10-29 04:32:43,026-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:0, Accuracy:0.9086538461538461.
# 2023-10-29 04:33:25,969-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:1, Accuracy:0.9663461538461539.
# 2023-10-29 04:34:07,205-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:2, Accuracy:0.9519230769230769.
# 2023-10-29 04:34:47,510-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:3, Accuracy:0.9519230769230769.
# 2023-10-29 04:35:29,115-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:4, Accuracy:0.8990384615384616.
# 2023-10-29 04:36:10,543-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:5, Accuracy:0.9158653846153846.
# 2023-10-29 04:36:51,711-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:6, Accuracy:0.9326923076923077.
# 2023-10-29 04:37:33,378-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:7, Accuracy:0.8846153846153846.
# 2023-10-29 04:38:15,105-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:8, Accuracy:0.8509615384615384.
# 2023-10-29 04:38:56,694-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:9, Accuracy:0.8725961538461539.
# 2023-10-29 04:39:38,214-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:10, Accuracy:0.8870192307692307.
# 2023-10-29 04:40:19,503-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:11, Accuracy:0.8557692307692308.
# 2023-10-29 04:41:00,776-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:12, Accuracy:0.8798076923076923.
# 2023-10-29 04:41:42,361-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:13, Accuracy:0.8629807692307692.
# 2023-10-29 04:42:23,887-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:14, Accuracy:0.8557692307692308.
# 2023-10-29 04:43:05,457-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:15, Accuracy:0.8605769230769231.
# 2023-10-29 04:43:46,928-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:16, Accuracy:0.8605769230769231.
# 2023-10-29 04:44:28,167-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:17, Accuracy:0.8533653846153846.
# 2023-10-29 04:45:09,236-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:18, Accuracy:0.84375.
# 2023-10-29 04:45:50,086-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:19, Accuracy:0.8581730769230769.
# 2023-10-29 04:46:31,203-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:20, Accuracy:0.8653846153846154.
# 2023-10-29 04:47:12,365-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:21, Accuracy:0.8557692307692308.
# 2023-10-29 04:47:53,770-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:22, Accuracy:0.8653846153846154.
# 2023-10-29 04:48:35,150-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:23, Accuracy:0.8557692307692308.
# 2023-10-29 04:49:16,409-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:24, Accuracy:0.8509615384615384.
# 2023-10-29 04:49:57,601-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:25, Accuracy:0.8461538461538461.
# 2023-10-29 04:50:38,826-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:26, Accuracy:0.8509615384615384.
# 2023-10-29 04:51:20,246-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:27, Accuracy:0.8509615384615384.
# 2023-10-29 04:52:01,385-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:28, Accuracy:0.8485576923076923.
# 2023-10-29 04:52:43,337-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:29, Accuracy:0.8533653846153846.
# 2023-10-29 04:53:24,585-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:30, Accuracy:0.8629807692307692.
# 2023-10-29 04:54:05,710-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:31, Accuracy:0.875.
# 2023-10-29 04:54:47,226-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:32, Accuracy:0.8798076923076923.
# 2023-10-29 04:55:28,788-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:33, Accuracy:0.8653846153846154.
# 2023-10-29 04:56:10,391-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:34, Accuracy:0.875.
# 2023-10-29 04:56:52,135-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:35, Accuracy:0.9182692307692307.
# 2023-10-29 04:57:33,507-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:36, Accuracy:0.8822115384615384.
# 2023-10-29 04:58:14,919-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:37, Accuracy:0.8557692307692308.
# 2023-10-29 04:58:56,803-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:38, Accuracy:0.875.
# 2023-10-29 04:59:38,333-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:39, Accuracy:0.8774038461538461.
# 2023-10-29 05:00:19,448-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:40, Accuracy:0.8701923076923077.
# 2023-10-29 05:01:00,785-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:41, Accuracy:0.9038461538461539.
# 2023-10-29 05:01:42,016-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:42, Accuracy:0.9134615384615384.
# 2023-10-29 05:02:23,534-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:43, Accuracy:0.875.
# 2023-10-29 05:03:06,858-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:44, Accuracy:0.8605769230769231.
# 2023-10-29 05:03:50,913-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:45, Accuracy:0.875.
# 2023-10-29 05:04:34,894-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:46, Accuracy:0.8701923076923077.
# 2023-10-29 05:05:18,970-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:47, Accuracy:0.8725961538461539.
# 2023-10-29 05:06:03,264-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:48, Accuracy:0.8677884615384616.
# 2023-10-29 05:06:47,324-INFO: Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:49, Accuracy:0.8774038461538461.
# 2023-10-29 05:06:47,324-INFO: Final Fusion Model:_hospital_sim-room, Agg_method:server_aggregate_simple, Best Accuracy:0.9663461538461539.
# 2023-10-29 05:06:47,633-INFO: -----------------------Fusion model names:_hospital_warehouse--------------------------
# 2023-10-29 05:07:39,136-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:0, Accuracy:0.8509615384615384.
# 2023-10-29 05:08:34,113-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:1, Accuracy:0.8533653846153846.
# 2023-10-29 05:09:27,197-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:2, Accuracy:0.8557692307692308.
# 2023-10-29 05:10:19,526-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:3, Accuracy:0.8605769230769231.
# 2023-10-29 05:11:11,912-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:4, Accuracy:0.8533653846153846.
# 2023-10-29 05:12:03,820-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:5, Accuracy:0.8533653846153846.
# 2023-10-29 05:12:55,914-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:6, Accuracy:0.8581730769230769.
# 2023-10-29 05:13:48,198-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:7, Accuracy:0.8629807692307692.
# 2023-10-29 05:14:42,509-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:8, Accuracy:0.8677884615384616.
# 2023-10-29 05:15:35,106-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:9, Accuracy:0.8629807692307692.
# 2023-10-29 05:16:27,342-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:10, Accuracy:0.875.
# 2023-10-29 05:17:19,290-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:11, Accuracy:0.8774038461538461.
# 2023-10-29 05:18:11,774-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:12, Accuracy:0.875.
# 2023-10-29 05:19:03,426-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:13, Accuracy:0.8701923076923077.
# 2023-10-29 05:19:55,228-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:14, Accuracy:0.8725961538461539.
# 2023-10-29 05:20:47,256-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:15, Accuracy:0.8798076923076923.
# 2023-10-29 05:21:39,384-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:16, Accuracy:0.8918269230769231.
# 2023-10-29 05:22:31,614-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:17, Accuracy:0.8822115384615384.
# 2023-10-29 05:23:23,491-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:18, Accuracy:0.8822115384615384.
# 2023-10-29 05:24:15,205-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:19, Accuracy:0.8798076923076923.
# 2023-10-29 05:25:07,026-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:20, Accuracy:0.8870192307692307.
# 2023-10-29 05:25:59,036-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:21, Accuracy:0.8894230769230769.
# 2023-10-29 05:26:50,724-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:22, Accuracy:0.8846153846153846.
# 2023-10-29 05:27:42,468-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:23, Accuracy:0.875.
# 2023-10-29 05:28:34,749-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:24, Accuracy:0.875.
# 2023-10-29 05:29:26,986-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:25, Accuracy:0.8846153846153846.
# 2023-10-29 05:30:19,510-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:26, Accuracy:0.8942307692307693.
# 2023-10-29 05:31:12,221-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:27, Accuracy:0.8918269230769231.
# 2023-10-29 05:32:04,348-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:28, Accuracy:0.8846153846153846.
# 2023-10-29 05:32:56,736-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:29, Accuracy:0.8966346153846154.
# 2023-10-29 05:33:49,602-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:30, Accuracy:0.8870192307692307.
# 2023-10-29 05:34:41,582-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:31, Accuracy:0.8990384615384616.
# 2023-10-29 05:35:33,714-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:32, Accuracy:0.8966346153846154.
# 2023-10-29 05:36:25,373-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:33, Accuracy:0.8966346153846154.
# 2023-10-29 05:37:17,485-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:34, Accuracy:0.8990384615384616.
# 2023-10-29 05:38:09,340-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:35, Accuracy:0.8918269230769231.
# 2023-10-29 05:39:01,252-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:36, Accuracy:0.9158653846153846.
# 2023-10-29 05:39:53,566-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:37, Accuracy:0.9014423076923077.
# 2023-10-29 05:40:45,508-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:38, Accuracy:0.9206730769230769.
# 2023-10-29 05:41:37,863-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:39, Accuracy:0.9014423076923077.
# 2023-10-29 05:42:29,743-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:40, Accuracy:0.9110576923076923.
# 2023-10-29 05:43:21,773-INFO: Fusion Model:_hospital_warehouse, Agg_method:server_aggregate_simple, Epoch:overall, Val_Data:41, Accuracy:0.8942307692307693.
# ...
# 2023-10-29 22:46:02,952-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:8, Accuracy:0.8725961538461539.
# 2023-10-29 22:46:52,894-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:9, Accuracy:0.8798076923076923.
# 2023-10-29 22:47:42,915-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:10, Accuracy:0.8774038461538461.
# 2023-10-29 22:48:33,259-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:11, Accuracy:0.875.
# 2023-10-29 22:49:31,817-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:12, Accuracy:0.8774038461538461.
# 2023-10-29 22:50:34,044-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:13, Accuracy:0.8774038461538461.
# 2023-10-29 22:51:47,795-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:14, Accuracy:0.8774038461538461.
# 2023-10-29 22:52:52,772-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:15, Accuracy:0.8798076923076923.
# 2023-10-29 22:53:56,496-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:16, Accuracy:0.8774038461538461.
# 2023-10-29 22:55:00,660-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:17, Accuracy:0.875.
# 2023-10-29 22:56:04,786-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:18, Accuracy:0.8774038461538461.
# 2023-10-29 22:57:08,894-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:19, Accuracy:0.8798076923076923.
# 2023-10-29 22:58:12,432-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:20, Accuracy:0.8798076923076923.
# 2023-10-29 22:59:15,266-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:21, Accuracy:0.875.
# 2023-10-29 23:00:04,072-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:22, Accuracy:0.8774038461538461.
# 2023-10-29 23:00:52,519-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:23, Accuracy:0.875.
# 2023-10-29 23:01:55,606-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:24, Accuracy:0.8774038461538461.
# 2023-10-29 23:02:55,994-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:25, Accuracy:0.875.
# 2023-10-29 23:03:56,086-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:26, Accuracy:0.875.
# 2023-10-29 23:04:58,400-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:27, Accuracy:0.8774038461538461.
# 2023-10-29 23:06:00,268-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:28, Accuracy:0.875.
# 2023-10-29 23:07:02,132-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:29, Accuracy:0.875.
# 2023-10-29 23:08:04,177-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:30, Accuracy:0.8798076923076923.
# 2023-10-29 23:09:05,927-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:31, Accuracy:0.875.
# 2023-10-29 23:10:07,273-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:32, Accuracy:0.875.
# 2023-10-29 23:11:09,286-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:33, Accuracy:0.8774038461538461.
# 2023-10-29 23:12:11,209-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:34, Accuracy:0.8774038461538461.
# 2023-10-29 23:13:13,134-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:35, Accuracy:0.8774038461538461.
# 2023-10-29 23:14:13,991-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:36, Accuracy:0.875.
# 2023-10-29 23:15:15,381-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:37, Accuracy:0.8798076923076923.
# 2023-10-29 23:16:16,485-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:38, Accuracy:0.8798076923076923.
# 2023-10-29 23:17:17,375-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:39, Accuracy:0.8774038461538461.
# 2023-10-29 23:18:18,916-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:40, Accuracy:0.8774038461538461.
# 2023-10-29 23:19:19,570-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:41, Accuracy:0.875.
# 2023-10-29 23:20:20,673-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:42, Accuracy:0.8774038461538461.
# 2023-10-29 23:21:22,614-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:43, Accuracy:0.8774038461538461.
# 2023-10-29 23:22:24,104-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:44, Accuracy:0.875.
# 2023-10-29 23:23:25,433-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:45, Accuracy:0.875.
# 2023-10-29 23:24:26,676-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:46, Accuracy:0.8798076923076923.
# 2023-10-29 23:25:27,830-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:47, Accuracy:0.875.
# 2023-10-29 23:26:28,559-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:48, Accuracy:0.8774038461538461.
# 2023-10-29 23:27:29,535-INFO: Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:49, Accuracy:0.8798076923076923.
# 2023-10-29 23:27:29,535-INFO: Final Fusion Model:_sim-room_warehouse, Agg_method:server_aggregate_quantization, Best Accuracy:0.8798076923076923.
# 2023-10-29 23:27:30,125-INFO: -----------------------Fusion model names:_hospital_sim-room_warehouse--------------------------
# 2023-10-29 23:28:55,942-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:0, Accuracy:0.8846153846153846.
# 2023-10-29 23:30:19,171-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:1, Accuracy:0.9591346153846154.
# 2023-10-29 23:31:42,608-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:2, Accuracy:0.9447115384615384.
# 2023-10-29 23:33:03,594-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:3, Accuracy:0.9423076923076923.
# 2023-10-29 23:34:26,106-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:4, Accuracy:0.9567307692307693.
# 2023-10-29 23:35:38,312-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:5, Accuracy:0.9519230769230769.
# 2023-10-29 23:36:40,719-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:6, Accuracy:0.9471153846153846.
# 2023-10-29 23:37:42,957-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:7, Accuracy:0.9663461538461539.
# 2023-10-29 23:38:45,341-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:8, Accuracy:0.9615384615384616.
# 2023-10-29 23:39:47,090-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:9, Accuracy:0.96875.
# 2023-10-29 23:40:49,138-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:10, Accuracy:0.9735576923076923.
# 2023-10-29 23:41:52,371-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:11, Accuracy:0.9735576923076923.
# 2023-10-29 23:42:54,602-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:12, Accuracy:0.9735576923076923.
# 2023-10-29 23:43:58,525-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:13, Accuracy:0.9711538461538461.
# 2023-10-29 23:45:00,988-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:14, Accuracy:0.9663461538461539.
# 2023-10-29 23:46:02,646-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:15, Accuracy:0.9711538461538461.
# 2023-10-29 23:47:04,188-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:16, Accuracy:0.9711538461538461.
# 2023-10-29 23:48:05,558-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:17, Accuracy:0.9783653846153846.
# 2023-10-29 23:49:08,052-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:18, Accuracy:0.9807692307692307.
# 2023-10-29 23:50:10,048-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:19, Accuracy:0.9759615384615384.
# 2023-10-29 23:51:12,040-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:20, Accuracy:0.9783653846153846.
# 2023-10-29 23:52:13,676-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:21, Accuracy:0.9759615384615384.
# 2023-10-29 23:53:15,521-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:22, Accuracy:0.9831730769230769.
# 2023-10-29 23:54:17,646-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:23, Accuracy:0.9807692307692307.
# 2023-10-29 23:55:19,239-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:24, Accuracy:0.9831730769230769.
# 2023-10-29 23:56:20,688-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:25, Accuracy:0.9807692307692307.
# 2023-10-29 23:57:25,279-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:26, Accuracy:0.9783653846153846.
# 2023-10-29 23:58:29,969-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:27, Accuracy:0.9807692307692307.
# 2023-10-29 23:59:31,846-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:28, Accuracy:0.9783653846153846.
# 2023-10-30 00:00:35,099-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:29, Accuracy:0.9807692307692307.
# 2023-10-30 00:01:36,657-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:30, Accuracy:0.9807692307692307.
# 2023-10-30 00:02:38,357-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:31, Accuracy:0.9783653846153846.
# 2023-10-30 00:03:43,417-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:32, Accuracy:0.9783653846153846.
# 2023-10-30 00:04:49,168-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:33, Accuracy:0.9831730769230769.
# 2023-10-30 00:05:54,791-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:34, Accuracy:0.9759615384615384.
# 2023-10-30 00:07:01,424-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:35, Accuracy:0.9831730769230769.
# 2023-10-30 00:08:07,391-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:36, Accuracy:0.9759615384615384.
# 2023-10-30 00:09:13,434-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:37, Accuracy:0.9735576923076923.
# 2023-10-30 00:10:20,110-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:38, Accuracy:0.9783653846153846.
# 2023-10-30 00:11:25,722-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:39, Accuracy:0.9831730769230769.
# 2023-10-30 00:12:31,359-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:40, Accuracy:0.9783653846153846.
# 2023-10-30 00:13:37,347-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:41, Accuracy:0.9783653846153846.
# 2023-10-30 00:14:42,677-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:42, Accuracy:0.9783653846153846.
# 2023-10-30 00:15:48,912-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:43, Accuracy:0.9783653846153846.
# 2023-10-30 00:16:53,841-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:44, Accuracy:0.9831730769230769.
# 2023-10-30 00:17:58,795-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:45, Accuracy:0.9783653846153846.
# 2023-10-30 00:19:03,724-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:46, Accuracy:0.9855769230769231.
# 2023-10-30 00:20:10,025-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:47, Accuracy:0.9879807692307693.
# 2023-10-30 00:21:16,861-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:48, Accuracy:0.9807692307692307.
# 2023-10-30 00:22:23,052-INFO: Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Epoch:overall, Val_Data:49, Accuracy:0.9807692307692307.
# 2023-10-30 00:22:23,052-INFO: Final Fusion Model:_hospital_sim-room_warehouse, Agg_method:server_aggregate_quantization, Best Accuracy:0.9879807692307693.
# 2023-10-30 00:22:23,076-INFO: ---------------Agg_method:server_aggregate_quantization:DONE!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!---------------.
# 2023-10-30 00:22:23,478-INFO: DONE!!!!!!!!
